# %%
import altair as alt
import pandas as pd
import sys
sys.path.append('figure_scripts/')
import plot_scripts as ps

# %%
RUN_TYPES = ['noN_filtered_15_85_human_REMM_revel_mvp_PSF0_501_noWL_genomiser', #default
             'noN_filtered_15_18_human_REMM_revel_mvp_alphaM_spliceAI_PSF_501_reg_filter_noWL_genomiser', #default + AM + splice
             'noN_filtered_15_85_human_REMM_cadd_revel_mvp_alphaM_spliceAI_PSF0_501_noWL_genomiser', #default + AM SPLICE CADD
             'noN_filtered_15_85_human_REMM_revel_mvp_alphaM_spliceAI_PP_MT_SIFT_PSF0_501_noWL_genomiser' , # #everything bud CADD
             'noN_filtered_15_85_human_revel_mvp_alphaM_spliceAI_PSF0_501_noWL_genomiser', ##no ReMM
             'noN_filtered_15_85_human_REMM_PP_MT_SIFT_PSF0_501_noWL_genomiser'] # ReMM + PP + MT +SIFT

# %%
success_table = pd.read_csv('../../02_exomiser_manuscript/supp_fig_08/genomiser_variant_paths_v2.tsv', sep='\t')

# %% [markdown]
# ## A: Combinations of path predictors

# %%
combo_df,denom = ps.create_df(2021, RUN_TYPES, success_table)
combo_plot=ps.create_plot(denom, combo_df, RUN_TYPES, 'set2', False,RUN_TYPES).properties(
        width=500,
        height=300)
combo_plot
# Out:
# noN_filtered_15_85_human_REMM_revel_mvp_PSF0_501_noWL_genomiser highest rank: 930.0 max%: 60.0 36
# noN_filtered_15_18_human_REMM_revel_mvp_alphaM_spliceAI_PSF_501_reg_filter_noWL_genomiser highest rank: 448.0 max%: 68.33333333333333 41
# noN_filtered_15_85_human_REMM_cadd_revel_mvp_alphaM_spliceAI_PSF0_501_noWL_genomiser highest rank: 343.0 max%: 73.33333333333333 44
# noN_filtered_15_85_human_REMM_revel_mvp_alphaM_spliceAI_PP_MT_SIFT_PSF0_501_noWL_genomiser highest rank: 454.0 max%: 68.33333333333333 41
# noN_filtered_15_85_human_revel_mvp_alphaM_spliceAI_PSF0_501_noWL_genomiser highest rank: 109.0 max%: 70.0 42
# noN_filtered_15_85_human_REMM_PP_MT_SIFT_PSF0_501_noWL_genomiser highest rank: 937.0 max%: 61.66666666666667 37
# alt.Chart(...)

# %% [markdown]
# ## B-E: Distribution of score values

# %%
order=['NONE', 'ALPHA_MISSENSE', 'MVP', 'REVEL', 'SPLICE_AI', 'CADD','MUTATION_TASTER', 'POLYPHEN', 'SIFT','REMM', 'Not_Prioritized']

# %%
default = ps.create_score_plot('noN_filtered_15_85_human_REMM_revel_mvp_PSF0_501_noWL_genomiser', success_table, order)
remm_revel_mvp_am_splice = ps.create_score_plot('noN_filtered_15_18_human_REMM_revel_mvp_alphaM_spliceAI_PSF_501_reg_filter_noWL_genomiser', success_table, order)
no_remm = ps.create_score_plot('noN_filtered_15_85_human_revel_mvp_alphaM_spliceAI_PSF0_501_noWL_genomiser', success_table, order)
remm_cadd = ps.create_score_plot('noN_filtered_15_85_human_REMM_cadd_revel_mvp_alphaM_spliceAI_PSF0_501_noWL_genomiser', success_table, order)
remm_revel_mvp_am_splice_pp_mt_sift = ps.create_score_plot('noN_filtered_15_85_human_REMM_revel_mvp_alphaM_spliceAI_PP_MT_SIFT_PSF0_501_noWL_genomiser', success_table, order)

# %%
score_panel = alt.vconcat(alt.hconcat(remm_revel_mvp_am_splice, no_remm), alt.hconcat(remm_cadd,remm_revel_mvp_am_splice_pp_mt_sift))
# score_panel

# %% [markdown]
# ## F-G: Distribution of maximum pathogenicity SOURCE

# %%
RUN_TYPES = ['noN_filtered_15_85_human_REMM_revel_mvp_PSF0.501_noWL_genomiser', #default
             'noN_filtered_15_18_human_REMM_revel_mvp_alphaM_spliceAI_PSF_501_reg_filter_noWL_genomiser', #default + AM + splice
             'noN_filtered_15_85_human_REMM_cadd_revel_mvp_alphaM_spliceAI_PSF0.501_noWL_genomiser', #default + AM SPLICE CADD
             'noN_filtered_15_85_human_REMM_revel_mvp_alphaM_spliceAI_PP_MT_SIFT_PSF0.501_noWL_genomiser' , # #everything bud CADD
             'noN_filtered_15_85_human_revel_mvp_alphaM_spliceAI_PSF0.501_noWL_genomiser', ##no ReMM
             'noN_filtered_15_85_human_REMM_PP_MT_SIFT_PSF0.501_noWL_genomiser'] # ReMM + PP + MT +SIFT



all_results=pd.read_csv('../../02_exomiser_manuscript/supp_fig_08/GS_genomiser_all_results_path_source_combos.tsv', sep='\t')
all_results['variant'] = [x.split('_')[0] for x in all_results['ID']]
all_results = all_results[all_results['RunType']!= 'noN_filtered_15_85_human_REMM_revel_mvp_PP_MT_SIFT_PSF0.501_noWL_genomiser']
#success_table['variant'] = [x.split('_')[0] for x in success_table['variant_exomiser_form']]
import numpy as np
all_results['id_variant'] = np.array(all_results['Patient_ID']) + '_' + np.array(all_results['variant'])
success_table['UDN_ID'] =[x.split('_')[0] for x in list(success_table['ID'])]
success_table['id_variant'] = np.array(success_table['UDN_ID']) + '_' + np.array(success_table['genomic_coordinates_hg38'])
all_results.fillna('NONE', inplace=True)
# Out:
# /tmp/ipykernel_606557/726662563.py:18: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'NONE' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   all_results.fillna('NONE', inplace=True)

# %%
non_diagnostic = all_results[~all_results['id_variant'].isin(list(success_table['id_variant']))]
diagnostic = all_results[all_results['id_variant'].isin(list(success_table['id_variant']))]

# %%
for RUN_TYPE in RUN_TYPES:
    #results = all_results[all_results['RunType']==RUN_TYPE]
    results = non_diagnostic[non_diagnostic['RunType']==RUN_TYPE]
    results_noNone = results[results['MAX_PATH'] != 'NONE']
    print(RUN_TYPE, len(results_noNone))
# Out:
# noN_filtered_15_85_human_REMM_revel_mvp_PSF0.501_noWL_genomiser 60779
# noN_filtered_15_18_human_REMM_revel_mvp_alphaM_spliceAI_PSF_501_reg_filter_noWL_genomiser 60831
# noN_filtered_15_85_human_REMM_cadd_revel_mvp_alphaM_spliceAI_PSF0.501_noWL_genomiser 61606
# noN_filtered_15_85_human_REMM_revel_mvp_alphaM_spliceAI_PP_MT_SIFT_PSF0.501_noWL_genomiser 60852
# noN_filtered_15_85_human_revel_mvp_alphaM_spliceAI_PSF0.501_noWL_genomiser 1936
# noN_filtered_15_85_human_REMM_PP_MT_SIFT_PSF0.501_noWL_genomiser 60810

# %%
data = []
for RUN_TYPE in RUN_TYPES:
    results = non_diagnostic[non_diagnostic['RunType']==RUN_TYPE]
    results_noNone = results[results['MAX_PATH'] != 'NONE']
    print(RUN_TYPE, len(results_noNone))

    for path_source in order:
        path = results_noNone[results_noNone['MAX_PATH_SOURCE']==path_source]
        data.append([RUN_TYPE, path_source, len(path), len(path)/len(results_noNone), len(results)])
        df = pd.DataFrame(data, columns=['RunType', 'MAX_PATH_SOURCE', 'num', 'percentage', 'all_runtype'])
        
base=alt.Chart(df,title='Max path sources for NONDIAGNOSTIC variants')       
bars = base.mark_bar().encode(
    alt.X('RunType:N', sort=RUN_TYPES),
    alt.Y('num:Q', title='Number of variants'),
    color=alt.Color('MAX_PATH_SOURCE:N', sort=order, scale=alt.Scale(scheme='tableau20', domain=order)),
    tooltip=['RunType:N','MAX_PATH_SOURCE', 'num:Q', 'percentage']

).properties(width=400, height=200)
text = base.mark_point(
    align='left',
    baseline='middle',
    #dx=-5,
    #dy=-10,
    strokeDash=[5,1],
    size=5000
  
).encode(
    y=alt.Y('all_runtype:Q').axis(offset=5, domainOpacity=0),
    x=alt.X('RunType:N', sort=RUN_TYPES), 
    color=alt.value('black'),
    shape=alt.Shape('RunType:N',scale = alt.Scale(range=["stroke"])),
    text='all_runtype:Q'
)
all_variants = alt.layer(bars, text).resolve_scale(color='independent')
# Out:
# noN_filtered_15_85_human_REMM_revel_mvp_PSF0.501_noWL_genomiser 60779
# noN_filtered_15_18_human_REMM_revel_mvp_alphaM_spliceAI_PSF_501_reg_filter_noWL_genomiser 60831
# noN_filtered_15_85_human_REMM_cadd_revel_mvp_alphaM_spliceAI_PSF0.501_noWL_genomiser 61606
# noN_filtered_15_85_human_REMM_revel_mvp_alphaM_spliceAI_PP_MT_SIFT_PSF0.501_noWL_genomiser 60852
# noN_filtered_15_85_human_revel_mvp_alphaM_spliceAI_PSF0.501_noWL_genomiser 1936
# noN_filtered_15_85_human_REMM_PP_MT_SIFT_PSF0.501_noWL_genomiser 60810

# %%
RUN_TYPES = ['noN_filtered_15_85_human_REMM_revel_mvp_PSF0_501_noWL_genomiser', #default
             'noN_filtered_15_18_human_REMM_revel_mvp_alphaM_spliceAI_PSF_501_reg_filter_noWL_genomiser', #default + AM + splice
             'noN_filtered_15_85_human_REMM_cadd_revel_mvp_alphaM_spliceAI_PSF0_501_noWL_genomiser', #default + AM SPLICE CADD
             'noN_filtered_15_85_human_REMM_revel_mvp_alphaM_spliceAI_PP_MT_SIFT_PSF0_501_noWL_genomiser' , # #everything bud CADD
             'noN_filtered_15_85_human_revel_mvp_alphaM_spliceAI_PSF0_501_noWL_genomiser', ##no ReMM
             'noN_filtered_15_85_human_REMM_PP_MT_SIFT_PSF0_501_noWL_genomiser'] # ReMM + PP + MT +SIFT

data = []
for RUN_TYPE in RUN_TYPES:
    results = success_table[success_table['Variant_Level_noMOI_' + str(RUN_TYPE)]=='Variant_Present_noMOI']
    results_noNone = results[results['Variant_Level_noMOI_maxPathSource_'+str(RUN_TYPE)] != 'NONE']
    max_paths = list(results_noNone['Variant_Level_noMOI_maxPathSource_'+str(RUN_TYPE)])
    print(RUN_TYPE, len(results))

    for path_source in order:
        num_path = max_paths.count(path_source)
      #  print(path_source, len(path))
        data.append([RUN_TYPE, path_source, num_path, num_path/len(max_paths), len(results)])

df = pd.DataFrame(data, columns=['RunType', 'MAX_PATH_SOURCE', 'num', 'percentage', 'all_runtype'])

base = alt.Chart(df,title='Max path sources for DIAGNOSTIC variants')
bars =base.mark_bar().encode(
    alt.X('RunType:N', sort=RUN_TYPES),
    alt.Y('num:Q', title='Number of variants (max=296)'),
    color=alt.Color('MAX_PATH_SOURCE:N', sort=order, scale=alt.Scale(scheme='tableau20', domain=order))

).properties(width=400, height=200)
text = base.mark_point(
    align='left',
    baseline='middle',
    dx=-5,
    dy=-10,
    color='black',
    strokeDash=[5,1],
    size=5000
).encode(
    y=alt.Y('all_runtype:Q').axis(offset=5, domainOpacity=0),
    x=alt.X('RunType:N', sort=RUN_TYPES), 
    color=alt.value('black'),
    shape=alt.Shape('RunType:N',scale = alt.Scale(range=["stroke"])),
    text='all_runtype:Q'
)

text2 = base.mark_text(
    align='left',
    baseline='middle',
    dx=-5,
    dy=-5,
    color='black',

).encode(
    y=alt.Y('all_runtype:Q').axis(offset=5, domainOpacity=0),
    x=alt.X('RunType:N', sort=RUN_TYPES), 
    color=alt.value('black'),
    text='all_runtype:Q'
)

diagnostic_variants = alt.layer(bars, text).resolve_scale(color='independent')
# Out:
# noN_filtered_15_85_human_REMM_revel_mvp_PSF0_501_noWL_genomiser 36
# noN_filtered_15_18_human_REMM_revel_mvp_alphaM_spliceAI_PSF_501_reg_filter_noWL_genomiser 41
# noN_filtered_15_85_human_REMM_cadd_revel_mvp_alphaM_spliceAI_PSF0_501_noWL_genomiser 44
# noN_filtered_15_85_human_REMM_revel_mvp_alphaM_spliceAI_PP_MT_SIFT_PSF0_501_noWL_genomiser 41
# noN_filtered_15_85_human_revel_mvp_alphaM_spliceAI_PSF0_501_noWL_genomiser 42
# noN_filtered_15_85_human_REMM_PP_MT_SIFT_PSF0_501_noWL_genomiser 37

# %%
variant_bars = alt.vconcat(all_variants, diagnostic_variants)
variant_bars
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ## H-I: Distribution of maximum pathogenicity SCORES

# %%
from pathlib import Path

tempdir = Path("./temp")
tempdir.mkdir(exist_ok=True)

source = tempdir / "data.json"
non_diagnostic[~non_diagnostic['MAX_PATH'].isin(['NONE' , 'Not_Prioritized'])].to_json(source, orient="records")

# %%
RUN_TYPES = ['noN_filtered_15_85_human_REMM_revel_mvp_PSF0.501_noWL_genomiser', #default
             'noN_filtered_15_18_human_REMM_revel_mvp_alphaM_spliceAI_PSF_501_reg_filter_noWL_genomiser', #default + AM + splice
             'noN_filtered_15_85_human_REMM_cadd_revel_mvp_alphaM_spliceAI_PSF0.501_noWL_genomiser', #default + AM SPLICE CADD
             'noN_filtered_15_85_human_REMM_revel_mvp_alphaM_spliceAI_PP_MT_SIFT_PSF0.501_noWL_genomiser' , # #everything bud CADD
             'noN_filtered_15_85_human_revel_mvp_alphaM_spliceAI_PSF0.501_noWL_genomiser', ##no ReMM
             'noN_filtered_15_85_human_REMM_PP_MT_SIFT_PSF0.501_noWL_genomiser'] # ReMM + PP + MT +SIFT

# %%
for run_type in RUN_TYPES:
    scores = non_diagnostic[non_diagnostic['RunType']==run_type]
    scores = scores[scores['MAX_PATH']!='NONE']
    print(run_type,len(scores))
# Out:
# noN_filtered_15_85_human_REMM_revel_mvp_PSF0.501_noWL_genomiser 60779
# noN_filtered_15_18_human_REMM_revel_mvp_alphaM_spliceAI_PSF_501_reg_filter_noWL_genomiser 60831
# noN_filtered_15_85_human_REMM_cadd_revel_mvp_alphaM_spliceAI_PSF0.501_noWL_genomiser 61606
# noN_filtered_15_85_human_REMM_revel_mvp_alphaM_spliceAI_PP_MT_SIFT_PSF0.501_noWL_genomiser 60852
# noN_filtered_15_85_human_revel_mvp_alphaM_spliceAI_PSF0.501_noWL_genomiser 1936
# noN_filtered_15_85_human_REMM_PP_MT_SIFT_PSF0.501_noWL_genomiser 60810

# %%
all_variants_max_path =alt.Chart(str(source), title='Variant path scores of NONDIAGNOSTIC variants').mark_boxplot().encode(
    alt.X("MAX_PATH:Q").scale(zero=False),
    alt.Y('RunType:N',sort=RUN_TYPES,title=None),#,axis=alt.Axis(labels=False)),
    color=alt.Color('RunType:N', scale=alt.Scale(scheme='set2', domain=RUN_TYPES))).properties(width=500)

# %%
all_variants_max_path
# Out:
# alt.Chart(...)

# %%
RUN_TYPES = ['noN_filtered_15_85_human_REMM_revel_mvp_PSF0_501_noWL_genomiser', #default
             'noN_filtered_15_18_human_REMM_revel_mvp_alphaM_spliceAI_PSF_501_reg_filter_noWL_genomiser', #default + AM + splice
             'noN_filtered_15_85_human_REMM_cadd_revel_mvp_alphaM_spliceAI_PSF0_501_noWL_genomiser', #default + AM SPLICE CADD
             'noN_filtered_15_85_human_REMM_revel_mvp_alphaM_spliceAI_PP_MT_SIFT_PSF0_501_noWL_genomiser' , # #everything bud CADD
             'noN_filtered_15_85_human_revel_mvp_alphaM_spliceAI_PSF0_501_noWL_genomiser', ##no ReMM
             'noN_filtered_15_85_human_REMM_PP_MT_SIFT_PSF0_501_noWL_genomiser'] # ReMM + PP + MT +SIFT
data = []
for run_type in RUN_TYPES:
    variant_scores = list(success_table['Variant_Level_noMOI_variant_'+run_type])
    for score in variant_scores:
        data.append([score, run_type])
df= pd.DataFrame(data, columns=['EXOMISER_VARIANT_SCORE', 'RunType'])


data2 = []
for run_type in RUN_TYPES:
    variant_scores = list(success_table['Variant_Level_noMOI_maxPath_'+run_type])
    for score in variant_scores:
        data2.append([score, run_type])
df2= pd.DataFrame(data2, columns=['MAX_PATH', 'RunType'])

# %%
diagnostic_only_maxpath =alt.Chart(df2, title='Pathogenicity score of DIAGNOSTIC variants only').mark_boxplot().encode(
    alt.X("MAX_PATH:Q").scale(zero=False,domain=[0,1]),
    alt.Y('RunType:N',sort=RUN_TYPES,title=None),
    color=alt.Color('RunType:N', scale=alt.Scale(scheme='set2', domain=RUN_TYPES))).properties(width=500)

# %%
score_distrib = alt.vconcat(diagnostic_only_maxpath, all_variants_max_path).resolve_scale(color='independent')

# %%
alt.hconcat(alt.vconcat(combo_plot, score_distrib), alt.vconcat(score_panel,variant_bars)).configure_axis(grid=True,
    labelPadding= 5,
    labelLimit=0,
    labelFontSize=15, 
    titleFontSize=15, labelFont='arial', tickSize=8).configure_legend(
        labelLimit=0,labelFontSize=15, titleFontSize=15, labelFont='arial')
# Out:
# alt.HConcatChart(...)
